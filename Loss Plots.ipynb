# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
FILE_TO_READ = "/data/model_runs/20211023T083631_agyelamayahdbp_LAMOL_MAML/dbpedia_loss.pickle"

# %%
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)

# %%
plt.plot(x)

# %%
FILE_TO_READ = "/data/model_runs/20220203T034532_ag1yelamayahdbp_LAMOL_MAML/yelp_loss.pickle"

# %%
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-5dae4bf611ac> in <module>
# ----> 1 with open(FILE_TO_READ, 'rb') as f:
#       2     x = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/model_runs/20220203T034532_ag1yelamayahdbp_LAMOL_MAML/yelp_loss.pickle'

# %%
plt.plot(x)

# %%
FILE_TO_READ = "/data/model_runs/20220203T034532_ag1yelamayahdbp_LAMOL_MAML/yahoo10k_loss.pickle"
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
plt.plot(x)

# %%
FILE_TO_READ = "/data/model_runs/20211023T083631_agyelamayahdbp_LAMOL_MAML/amazon_loss.pickle"
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
plt.plot(x)

# %%
FILE_TO_READ = "/data/model_runs/20220529T212429_1_oml2gpt2/yahoo_loss.pickle"
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
plt.plot(x)

# %%
FILE_TO_READ = "/data/model_runs/20220118T195023_dbpyahag1amayel_LAMOL/dbpedia10k_loss.pickle"
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
plt.plot(x[-1000:])

# %%
np.mean(x[-1000:])
# Out:
# 0.8779901340901851

# %%
FILE_TO_READ = "/data/model_runs/20211023T083631_agyelamayahdbp_LAMOL_MAML/yahoo_loss.pickle"
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
plt.plot(x[18000:])

# %%
np.mean(x[-5000:])
# Out:
# 0.772567961332202

# %%
FILE_TO_READ = "/data/model_runs/20210630T184801_mbs_SEQ_MAML/movie_loss.pickle"
FILE_TO_READ2 = "/data/model_runs/20210630T184801_mbs_SEQ_MAML/boolq_loss.pickle"
FILE_TO_READ3 = "/data/model_runs/20210630T184801_mbs_SEQ_MAML/scifact_loss.pickle"

# %%
with open(FILE_TO_READ, 'rb') as f:
    x = pickle.load(f)
with open(FILE_TO_READ2, 'rb') as f:
    x2 = pickle.load(f)
with open(FILE_TO_READ3, 'rb') as f:
    x3 = pickle.load(f)

# %%
plt.plot(x)

# %%
plt.plot(x2)

# %%
plt.plot(x3)
